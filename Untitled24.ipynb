# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 39.7 MB/s eta 0:00:00
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.204 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 39.4/112.6 GB disk)

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-14d058ef-aff2-4f68-9b36-3acc472f1e6a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-14d058ef-aff2-4f68-9b36-3acc472f1e6a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !unzip new_2.zip -d /content
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/new/train/images/IMG20241209154710_jpg.rf.d835fc6cddea7ff3f1bf8cb43236bb05.jpg
#   inflating: /content/new/train/images/IMG20241209154712_jpg.rf.084340551314796c880b61fa6f4fe63b.jpg
#   inflating: /content/new/train/images/IMG20241209154712_jpg.rf.94c1d9677e61c9057bd88ada86479681.jpg
#   inflating: /content/new/train/images/IMG20241209154712_jpg.rf.a2e8e8acc96a3a3b350edc63c0fb5391.jpg
#   inflating: /content/new/train/images/IMG20241209154712_jpg.rf.b2f48ec2b7b750ea7e89b29ec47e409c.jpg
#   inflating: /content/new/train/images/IMG20241209154714_jpg.rf.195a1d757d4e8264be8619e04c734bb7.jpg
#   inflating: /content/new/train/images/IMG20241209154714_jpg.rf.3aa72de244190b99d0ffdaeaa173fe56.jpg
#   inflating: /content/new/train/images/IMG20241209154714_jpg.rf.4d2ec814d4584771aba47321a37da135.jpg
#   inflating: /content/new/train/images/IMG20241209154714_jpg.rf.b0febae4651dd962a6c7deb4cb77c1cd.jpg
# ...

# %%
from ultralytics import YOLO


model = YOLO("yolov8m.pt")


model.train(
    data="/content/new/data.yaml",
    epochs=100,
    imgsz=640,
    batch=16,
    patience=15,
    device=0
)
# Out:
# ...
# Ultralytics 8.3.204 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...
